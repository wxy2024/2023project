# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline

data_all=pd.read_csv('data/data_all.csv')
df = data_all.copy()

# %%
df
# Out:
#     number                                        title          user  \
# 0     3148                              开了加速依然显示服务器连接失败        1517su
# 1     3147                              🐛[BUG] 正常使用中会闪退    lingfeng01
# 2     3144                     🐛[BUG] 开机启动任务计划请求的操作需要提升       Chun-J1
# 3     3143                   🧐[Question] windows睡眠 遊戲時數  Laijason9170
# 4     3142    🐛[BUG] GITHUB加速会出现SSL连不上，GITHUB.com 443报警  Lennonleslie
# ..     ...                                          ...           ...
# 85    2985                               Project Mobius        AigioL
# 86    2984                             🐛[BUG] 动态头像框显示异常    2315095914
# 87    2983                         🐛[BUG] 应用状态栏，会进行多重显示        Kee02p
# 88    2981        👑[Enhancement] 开机自启不显示切换账号且要手动授权管理员权限    2315095914
# 89    2980  系统崩溃之后 重新做了系统 令牌文件没了 我已经恢复了之前的数据 令牌是否能重新恢复上     waa123123
#
#              labels state  locked            created_at            updated_at  \
# 0      ['question']  open   False  2024-01-23T04:31:58Z  2024-01-23T04:31:58Z
# 1           ['bug']  open   False  2024-01-22T10:44:10Z  2024-01-22T16:04:07Z
# 2           ['bug']  open   False  2024-01-21T03:58:22Z  2024-01-21T03:58:47Z
# 3      ['question']  open   False  2024-01-20T05:39:46Z  2024-01-20T05:39:46Z
# 4           ['bug']  open   False  2024-01-19T04:20:36Z  2024-01-19T04:20:36Z
# ..              ...   ...     ...                   ...                   ...
# 85               []  open   False  2023-11-02T11:49:43Z  2023-11-02T11:49:43Z
# 86          ['bug']  open   False  2023-10-31T04:34:20Z  2023-10-31T04:34:56Z
# 87          ['bug']  open   False  2023-10-31T00:28:43Z  2023-11-13T06:40:06Z
# 88  ['enhancement']  open   False  2023-10-30T04:35:02Z  2023-11-13T06:42:52Z
# 89     ['question']  open   False  2023-10-28T05:25:35Z  2023-10-28T05:25:35Z
#
#     closed_at  comments
# 0         NaN         0
# 1         NaN         1
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0
# ..        ...       ...
# 85        NaN         0
# 86        NaN         0
# 87        NaN         1
# 88        NaN         1
# 89        NaN         0
#
# [90 rows x 10 columns]

# %%
df['created_at'] = pd.to_datetime(df['created_at'])
df['updated_at'] = pd.to_datetime(df['updated_at'])
df['closed_at'] = pd.to_datetime(df['closed_at'])

df
# Out:
#     number                                        title          user  \
# 0     3148                              开了加速依然显示服务器连接失败        1517su
# 1     3147                              🐛[BUG] 正常使用中会闪退    lingfeng01
# 2     3144                     🐛[BUG] 开机启动任务计划请求的操作需要提升       Chun-J1
# 3     3143                   🧐[Question] windows睡眠 遊戲時數  Laijason9170
# 4     3142    🐛[BUG] GITHUB加速会出现SSL连不上，GITHUB.com 443报警  Lennonleslie
# ..     ...                                          ...           ...
# 85    2985                               Project Mobius        AigioL
# 86    2984                             🐛[BUG] 动态头像框显示异常    2315095914
# 87    2983                         🐛[BUG] 应用状态栏，会进行多重显示        Kee02p
# 88    2981        👑[Enhancement] 开机自启不显示切换账号且要手动授权管理员权限    2315095914
# 89    2980  系统崩溃之后 重新做了系统 令牌文件没了 我已经恢复了之前的数据 令牌是否能重新恢复上     waa123123
#
#              labels state  locked                created_at  \
# 0      ['question']  open   False 2024-01-23 04:31:58+00:00
# 1           ['bug']  open   False 2024-01-22 10:44:10+00:00
# 2           ['bug']  open   False 2024-01-21 03:58:22+00:00
# 3      ['question']  open   False 2024-01-20 05:39:46+00:00
# 4           ['bug']  open   False 2024-01-19 04:20:36+00:00
# ..              ...   ...     ...                       ...
# 85               []  open   False 2023-11-02 11:49:43+00:00
# 86          ['bug']  open   False 2023-10-31 04:34:20+00:00
# 87          ['bug']  open   False 2023-10-31 00:28:43+00:00
# 88  ['enhancement']  open   False 2023-10-30 04:35:02+00:00
# 89     ['question']  open   False 2023-10-28 05:25:35+00:00
#
#                   updated_at closed_at  comments
# 0  2024-01-23 04:31:58+00:00       NaT         0
# 1  2024-01-22 16:04:07+00:00       NaT         1
# 2  2024-01-21 03:58:47+00:00       NaT         0
# 3  2024-01-20 05:39:46+00:00       NaT         0
# 4  2024-01-19 04:20:36+00:00       NaT         0
# ..                       ...       ...       ...
# 85 2023-11-02 11:49:43+00:00       NaT         0
# 86 2023-10-31 04:34:56+00:00       NaT         0
# 87 2023-11-13 06:40:06+00:00       NaT         1
# 88 2023-11-13 06:42:52+00:00       NaT         1
# 89 2023-10-28 05:25:35+00:00       NaT         0
#
# [90 rows x 10 columns]

# %%
monthly_counts = df.groupby([df['created_at'].dt.year, df['created_at'].dt.month]).size()
monthly_counts
# Out:
# created_at  created_at
# 2023        10             4
#             11            27
#             12            33
# 2024        1             26
# dtype: int64

# %%
monthly_counts = df.groupby(pd.Grouper(key='created_at',freq='M')).size()
monthly_counts.index = monthly_counts.index.strftime('%Y-%m')
monthly_counts
# Out:
# created_at
# 2023-10     4
# 2023-11    27
# 2023-12    33
# 2024-01    26
# dtype: int64

# %%
# 绘制直方图
plt.plot(monthly_counts,"o-")

# 添加标签和标题
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Monthly Counts')

# 显示图形
plt.show()
